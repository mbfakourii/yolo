# %% [markdown]
# **Go Main Directory in colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Deep/project_2
# Out:
# /content/drive/MyDrive/Deep/project_2

# %% [markdown]
# **install necessary libs**

# %%
# !apt install libopencv-dev python-opencv ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   python-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 535 kB of archives.
# After this operation, 2,944 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [535 kB]
# Fetched 535 kB in 1s (496 kB/s)
# Selecting previously unselected package python-opencv.
# (Reading database ... 160706 files and directories currently installed.)
# Preparing to unpack .../python-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# ...

# %% [markdown]
# **Create Test.txt And Train.txt file from picture (Path Images)**

# %%
# !python process.py
# Out:
# /content/drive/My Drive/Deep/project_2

# %% [markdown]
# **make execute file**

# %%
# !git clone https://github.com/AlexeyAB/darknet/

# !chmod 755 -R "darknet"
# %cd darknet/

# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !make
# Out:
# /content/drive/My Drive/Deep/project_2/darknet

# %% [markdown]
# **Train Network**

# %%
# !./darknet detector train ../configs/voc.data ../configs/yolov3.cfg -dont_show
# Out:
#  CUDA-version: 11000 (11020), GPU count: 1
#  OpenCV version: 3.2.0
# yolov3
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 3, batch = 24, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %% [markdown]
# **Test Images**

# %%
import cv2 as cv
from matplotlib import pyplot as plt
import os

def test(name):
  name = name.replace(' ', '\\ ')

  # !./darknet detector test ../configs/voc.data ../configs/yolov3.cfg ../backup/yolov3_last.weights -thresh 0.15 $name

  img = cv.imread("predictions.jpg",4)
  plt.figure(figsize = (20,20))
  plt.imshow(img)

test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t1.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t2.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t3.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t4.jpeg')
# test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t5.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t6.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t7.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t8.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t9.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t10.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t11.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t12.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t13.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t14.jpeg')
test(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/test/image/t15.jpeg')

# %% [markdown]
# **Test Video**

# %%
# !./darknet detector demo ../configs/voc.data ../configs/yolov3.cfg ../backup/yolov3_last.weights -dont_show ../test/video/test1.mp4 -out_filename ../test/video/test1_output.mp4
# !./darknet detector demo ../configs/voc.data ../configs/yolov3.cfg ../backup/yolov3_last.weights -dont_show ../test/video/test2.mp4 -out_filename ../test/video/test2_output.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# FPS:39.5 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.6 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
# Person: 46%
#
# FPS:37.8 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.6 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
# Person: 39%
#
# FPS:36.3 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
# Person: 33%
#
# FPS:36.4 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:36.1 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
# Person: 38%
#
# FPS:36.1 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
# Person: 35%
#
# FPS:35.7 	 AVG_FPS:34.6
#
#  cvWriteFrame
# Objects:
#
# Person: 42%
#
# FPS:36.5 	 AVG_FPS:34.6
#
# ...
