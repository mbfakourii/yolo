# %%
import glob
import os
import shutil
for filename in glob.glob(os.path.join("/content/drive/MyDrive/Deep/project_2/data/pictagiyolo/person", '*.*')):
  shutil.copy(filename, "/content/drive/MyDrive/Deep/project_2/data/renamepictagyolo/person")

# %%
import os

list = os.listdir("/content/drive/MyDrive/Deep/project_2/data/renamepictagyolo/person") # dir is your directory path
number_files = len(list)
number_files
# Out:
# 2676

# %%
import os
from shutil import copyfile

paths="/content/drive/MyDrive/Deep/project_2/data/renamepictagyolo/person"
list_names = []
for file in os.listdir(paths):
  filename, file_extension = os.path.splitext(file)
  if filename in list_names:
    print("")
  else:
   list_names.append(filename)
# print(list_names)
# print(len(list_names))

iii=0
for names in list_names:
  iii=iii+1
  for file in os.listdir(paths):
      filename, file_extension = os.path.splitext(os.path.join(file))
      if filename == names:
        # print(filename)
        # print(os.path.join(paths, file))
        # print(paths + "/person" + str(iii)+file_extension)
        os.rename(os.path.join(paths, file) , paths + "/person" + str(iii)+file_extension)

print("OK")
# Out:
# OK
